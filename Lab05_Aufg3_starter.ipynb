# %% [markdown]
# Gegeben seien die Matrix $\mathsf{M}$ und der Vektor $\vec{v}_0$,
# \begin{equation}
#   \mathsf{M}= \left(
#        \begin{matrix}
#            2 & -1 & 4 \\
#            -1 & 3 & 2 \\
#            4 & 2 & 1
#         \end{matrix}
#       \right)
#       \, , \quad
#       \vec{v}_0 = \left( \begin{matrix} 1 \\ 1 \\ 1 \end{matrix} \right) \, .
# \end{equation}
#
# Iterieren Sie einige Male die Vorschrift
# \begin{equation}
#    \vec{v}_{n+1} = \frac{\mathsf{M} \cdot \vec{v}_n}{||\mathsf{M} \cdot \vec{v}_n||_2} \, .
# \end{equation}
# Lassen Sie sich $\vec{v}_n$ und $||\vec{v}_n||_2$ während der Iteration ausgeben. Welche Beobachtung machen Sie?
# Was ist die Bedeutung des Vectors $\lim_{n\to \infty} \vec{v}_n$?

# %%
import numpy as np
import math as m
M = np.array([[2,-1,4],
             [-1,3,2],
             [4,2,1]])
v0 = np.array([1,1,1])
N = 50
for i in range(N):
    #for i2 in range(3):
       # norm2 += v0[i2]**2
    #norm = m.sqrt((
    multMv = np.dot(M,v0)
    v = (multMv)/(np.linalg.norm(multMv))
    v0 = v
    print('v%d '%(i), v)
    print('normv%d ='%(i),np.linalg.norm(v))
# Out:
# v0  [0.52704628 0.42163702 0.73786479]
# normv0 = 1.0
# v1  [0.64003012 0.39531272 0.65885454]
# normv1 = 1.0
# v2  [0.62285254 0.32974546 0.70945236]
# normv2 = 1.0
# v3  [0.66171665 0.31471173 0.68050541]
# normv3 = 1.0
# v4  [0.65668732 0.28927727 0.69647715]
# normv4 = 1.0
# v5  [0.6702485  0.2821898  0.68639337]
# normv5 = 1.0
# v6  [0.66901713 0.27245322 0.69150945]
# normv6 = 1.0
# v7  [0.67383447 0.26930761 0.68805561]
# normv7 = 0.9999999999999999
# v8  [0.67362825 0.26557652 0.6897058 ]
# normv8 = 1.0
# v9  [0.67536303 0.26422102 0.68852889]
# normv9 = 1.0
# v10  [0.67537987 0.26278544 0.68906157]
# normv10 = 0.9999999999999999
# v11  [0.67601142 0.26221189 0.68866065]
# normv11 = 1.0
# v12  [0.67605178 0.26165702 0.68883205]
# normv12 = 1.0
# v13  [0.67628388 0.26141738 0.68869519]
# normv13 = 0.9999999999999999
# v14  [0.67631129 0.26120198 0.68875   ]
# normv14 = 1.0
# v15  [0.67639733 0.26110278 0.68870312]
# normv15 = 1.0
# v16  [0.67641204 0.26101883 0.6887205 ]
# ...
